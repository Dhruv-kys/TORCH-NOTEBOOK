# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhruv-kys/TORCH-NOTEBOOK/blob/main/tensors_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# 2.11.0+cu128
# True
# 12.8

# %% [markdown]
# ### Creating a Tensor

# %%
a=torch.empty(2,3)

# %%
type(a)
# Out:
# torch.Tensor

# %%
b = torch.zeros(2,3)

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand(2,3)
# Out:
# tensor([[0.5433, 0.8343, 0.2196],
#         [0.3228, 0.6405, 0.2021]])

# %%
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
torch.tensor([[1,2,3],[4,5,6]])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %% [markdown]
# ### Tensor Shape

# %%
x = torch.tensor([[1,2,3],[4,5,6]])

# %%
x
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
x.shape
# Out:
# torch.Size([2, 3])

# %%
torch.empty_like(x)
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %%
torch.zeros_like(x)
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %% [markdown]
# ### Tensor Data Types

# %%
x.dtype
# Out:
# torch.int64

# %%
torch.tensor([1.0,2.0,3.0], dtype = torch.int32)
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
torch.tensor([1,2,3], dtype = torch.float64)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
x.to(torch.float)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %% [markdown]
# ### Tensor Operations on GPU

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### CPU vs GPU

# %%
import time

# Size of matrix
size = 10000

# Random matrices on CPU
matrix_cpu1 = torch.rand(size, size)
matrix_cpu2 = torch.rand(size, size)

# Time on CPU
start_time = time.time()
result_cpu = torch.matmul(matrix_cpu1, matrix_cpu2)
end_time = time.time()
cpu_time = end_time - start_time

print(f"Time taken on CPU: {cpu_time} seconds")

# Move matrices on GPU
matrix_gpu1 = matrix_cpu1.to(device)
matrix_gpu2 = matrix_cpu2.to(device)

# Time on GPU
start_time = time.time()
result_gpu = torch.matmul(matrix_gpu1, matrix_gpu2)
end_time = time.time()
gpu_time = end_time - start_time

print(f"Time taken on GPU: {gpu_time} seconds")
# Out:
# Time taken on CPU: 17.21718454360962 seconds
# Time taken on GPU: 0.11287260055541992 seconds
